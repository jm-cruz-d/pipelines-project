# %%
import pandas as pd
import numpy as np
import re as re
import requests
from bs4 import BeautifulSoup

# %%
import chardet

lfile = './input/top250-00-19.csv'
def openDf(x):
    with open(x, 'rb') as f:
        result = chardet.detect(f.read())
    return pd.read_csv(x, encoding=result['encoding'])

df = openDf(lfile)
print(df.shape)
# Out:
# (4700, 10)

# %%
df.dtypes
# Out:
# Name             object
# Position         object
# Age               int64
# Team_from        object
# League_from      object
# Team_to          object
# League_to        object
# Season           object
# Market_value    float64
# Transfer_fee      int64
# dtype: object

# %%
df.head()
#df.groupby(['Transfer_fee', 'Season']).max().sort_index(ascending=False)
# Out:
#                 Name        Position  Age     Team_from     League_from  \
# 0          Luís Figo    Right Winger   27  FC Barcelona          LaLiga
# 1      Hernán Crespo  Centre-Forward   25         Parma         Serie A
# 2      Marc Overmars     Left Winger   27       Arsenal  Premier League
# 3  Gabriel Batistuta  Centre-Forward   31    Fiorentina         Serie A
# 4     Nicolas Anelka  Centre-Forward   21   Real Madrid          LaLiga
#
#         Team_to League_to     Season  Market_value  Transfer_fee
# 0   Real Madrid    LaLiga  2000-2001           NaN      60000000
# 1         Lazio   Serie A  2000-2001           NaN      56810000
# 2  FC Barcelona    LaLiga  2000-2001           NaN      40000000
# 3       AS Roma   Serie A  2000-2001           NaN      36150000
# 4      Paris SG   Ligue 1  2000-2001           NaN      34500000

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# Name               0
# Position           0
# Age                0
# Team_from          0
# League_from        0
# Team_to            0
# League_to          0
# Season             0
# Market_value    1260
# Transfer_fee       0
# dtype: int64

# %%
def nullOut(x):
    null_cols = x.isnull().sum()
    return x.drop((list(null_cols[null_cols>1000].index)), axis=1)
df=nullOut(df)

# %%
def dropCol(x, y):
    return x.drop(columns=y)

df=dropCol(df,['Position','League_to', 'Age'])

# %%
def convMill(x, y):
    x[y]=x[y]/10**6
    return x

df = convMill(df, 'Transfer_fee')
df
# Out:
#                    Name       Team_from     League_from        Team_to  \
# 0             Luís Figo    FC Barcelona          LaLiga    Real Madrid
# 1         Hernán Crespo           Parma         Serie A          Lazio
# 2         Marc Overmars         Arsenal  Premier League   FC Barcelona
# 3     Gabriel Batistuta      Fiorentina         Serie A        AS Roma
# 4        Nicolas Anelka     Real Madrid          LaLiga       Paris SG
# ...                 ...             ...             ...            ...
# 4695      Jasmin Kurtic        Atalanta         Serie A           SPAL
# 4696          Tchê Tchê       Palmeiras         Série A    Dynamo Kyiv
# 4697      Silvan Widmer  Udinese Calcio         Serie A       FC Basel
# 4698         Yuya Osako      1. FC Köln    2.Bundesliga  Werder Bremen
# 4699       Kyle Bartley         Swansea    Championship      West Brom
#
#          Season  Transfer_fee
# 0     2000-2001         60.00
# 1     2000-2001         56.81
# 2     2000-2001         40.00
# 3     2000-2001         36.15
# 4     2000-2001         34.50
# ...         ...           ...
# 4695  2018-2019          4.80
# 4696  2018-2019          4.80
# 4697  2018-2019          4.50
# 4698  2018-2019          4.50
# 4699  2018-2019          4.50
#
# [4700 rows x 6 columns]

# %%
df.head()
# Out:
#                 Name     Team_from     League_from       Team_to     Season  \
# 0          Luís Figo  FC Barcelona          LaLiga   Real Madrid  2000-2001
# 1      Hernán Crespo         Parma         Serie A         Lazio  2000-2001
# 2      Marc Overmars       Arsenal  Premier League  FC Barcelona  2000-2001
# 3  Gabriel Batistuta    Fiorentina         Serie A       AS Roma  2000-2001
# 4     Nicolas Anelka   Real Madrid          LaLiga      Paris SG  2000-2001
#
#    Transfer_fee
# 0         60.00
# 1         56.81
# 2         40.00
# 3         36.15
# 4         34.50

# %%
print(sorted(set(df['League_from'])))
# Out:
# [' Argentina', ' Australia', ' Brazil', ' Bulgaria', ' Canada', ' Chile', ' China', ' Colombia', ' Croatia', ' Czech Republic', ' Denmark', ' Ecuador', ' England', ' Finland', ' France', ' Ghana', ' Iran', ' Korea, South', ' Latvia', ' Mexico', ' Moldova', ' Paraguay', ' Peru', ' Portugal', ' Qatar', ' Romania', ' Russia', ' Saudi Arabia', ' Scotland', ' Serbia', ' Slovakia', ' South Africa', ' Spain', ' Sweden', ' Tunisia', ' Ukraine', ' United Arab Emirates', ' United States', ' Uruguay', ' Venezuela', '1.Bundesliga', '1.Division', '1.HNL', '1.Lig', '1.Liga gr. 1', '2.Bundesliga', '2ª B - Grupo I', '2ª B - Grupo III', '3.Liga', 'A Grupa - Championship gr.', 'Allsvenskan', 'Auf-/Abstiegsrunde NLA/NLB', 'Botola Pro', 'Bundesliga', 'Challenge League', 'Championnat National', 'Championship', 'Ekstraklasa', 'Eliteserien', 'Eredivisie', 'First Division', 'HET Liga', 'J1 - 2nd Stage', 'J1 League', 'J2 League', 'Jupiler Pro League', 'K League 1', 'Korean FA Cup', 'LaLiga', 'LaLiga2', 'League One', 'Liga 1', 'Liga 1 - Championship group', 'Liga MX Apertura', 'Liga MX Clausura', 'Liga NOS', 'Liga Águila II', "Ligat ha'Al", 'Ligue 1', 'Ligue 2', 'Ligue I Pro', 'MLS', 'NB I.', 'OBOS-ligaen', 'Premier League', 'Premier Liga', 'Premiership', 'Primavera B', 'Primera B Nacional', 'Primera Div. Apertura', 'Primera División', 'Professional League', 'Proximus League', 'Regionalliga Nord', 'Rel. Ligue 1', 'Second Division (bis 03/04)', 'Segunda División', 'Serie A', 'Serie A Segunda Etapa', 'Serie B', 'Serie C - A', 'Serie C - B', 'Stars League', 'Super League', 'SuperLiga', 'Superettan', 'Superligaen', 'Superligaen Championship round', 'Série A', 'Série B', 'Süper Lig', 'Torneo Final', 'Torneo Inicial', 'U18 Premier League', 'U19 Eredivisie', 'UAE Gulf League', 'Virsliga', 'Vysheyshaya Liga']

# %%
probando = df[(df['League_from'] == 'Bundesliga')]
probando
# Out:
#                     Name       Team_from League_from          Team_to  \
# 484     Andrés Fleurquín      Sturm Graz  Bundesliga      Galatasaray
# 1343  Andreas Ivanschitz    Rapid Vienna  Bundesliga      RB Salzburg
# 1454       Rabiu Afolabi  Austria Vienna  Bundesliga       FC Sochaux
# 2377        Erwin Hoffer    Rapid Vienna  Bundesliga       SSC Napoli
# 2568          Marc Janko     RB Salzburg  Bundesliga        FC Twente
# 2625      Nikica Jelavic    Rapid Vienna  Bundesliga          Rangers
# 2922      Nacer Barazite  Austria Vienna  Bundesliga           Monaco
# 3489          Sadio Mané     RB Salzburg  Bundesliga      Southampton
# 3532         Kevin Kampl     RB Salzburg  Bundesliga    Bor. Dortmund
# 3539                Alan     RB Salzburg  Bundesliga    GZ Evergrande
# 3595         Omer Damari  Austria Vienna  Bundesliga       RB Leipzig
# 3897        Robert Beric    Rapid Vienna  Bundesliga    Saint-Étienne
# 4002          Naby Keïta     RB Salzburg  Bundesliga       RB Leipzig
# 4047     Jonatan Soriano     RB Salzburg  Bundesliga  BJ Sinobo Guoan
# 4113     Dayot Upamecano     RB Salzburg  Bundesliga       RB Leipzig
# 4188  Martin Hinteregger     RB Salzburg  Bundesliga      FC Augsburg
# 4422           Wanderson     RB Salzburg  Bundesliga        Krasnodar
# 4437    Maximilian Wöber    Rapid Vienna  Bundesliga         AFC Ajax
# 4448       Konrad Laimer     RB Salzburg  Bundesliga       RB Leipzig
# 4504     Duje Caleta-Car     RB Salzburg  Bundesliga        Marseille
# 4604       Valon Berisha     RB Salzburg  Bundesliga            Lazio
# 4622    Valentino Lazaro     RB Salzburg  Bundesliga       Hertha BSC
#
#          Season  Transfer_fee
# 484   2001-2002           2.0
# 1343  2005-2006           4.0
# 1454  2005-2006           2.0
# 2377  2009-2010           5.0
# 2568  2010-2011           7.0
# 2625  2010-2011           4.9
# 2922  2011-2012           4.5
# 3489  2014-2015          23.0
# 3532  2014-2015          12.0
# 3539  2014-2015          11.1
# 3595  2014-2015           7.0
# 3897  2015-2016           7.5
# 4002  2016-2017          24.0
# 4047  2016-2017          15.0
# 4113  2016-2017          10.0
# 4188  2016-2017           7.0
# 4422  2017-2018           8.0
# 4437  2017-2018           7.5
# 4448  2017-2018           7.0
# 4504  2018-2019          19.0
# 4604  2018-2019           7.5
# 4622  2018-2019           6.5

# %%
def generaFiltros(x, y, ligas):
    #filtrosLigas = dict()
    #for liga in ligas:
        #filtrosLigas[liga] = x.loc[(x['League_from'] == liga)]
    #for liga in ligas:
    prob = x[(x[y].isin(ligas))]
    return prob

z = ['Bundesliga','LaLiga','Premier League','League One', 'Serie A', 'Eredivisie']
df = generaFiltros(df, 'League_from', z)

# %%
df
# Out:
#                      Name       Team_from     League_from       Team_to  \
# 0               Luís Figo    FC Barcelona          LaLiga   Real Madrid
# 1           Hernán Crespo           Parma         Serie A         Lazio
# 2           Marc Overmars         Arsenal  Premier League  FC Barcelona
# 3       Gabriel Batistuta      Fiorentina         Serie A       AS Roma
# 4          Nicolas Anelka     Real Madrid          LaLiga      Paris SG
# ...                   ...             ...             ...           ...
# 4689         Jens Odgaard           Inter         Serie A      Sassuolo
# 4690        Marco Carraro           Inter         Serie A      Atalanta
# 4692  Giangiacomo Magnani        Juventus         Serie A      Sassuolo
# 4695        Jasmin Kurtic        Atalanta         Serie A          SPAL
# 4697        Silvan Widmer  Udinese Calcio         Serie A      FC Basel
#
#          Season  Transfer_fee
# 0     2000-2001         60.00
# 1     2000-2001         56.81
# 2     2000-2001         40.00
# 3     2000-2001         36.15
# 4     2000-2001         34.50
# ...         ...           ...
# 4689  2018-2019          5.00
# 4690  2018-2019          5.00
# 4692  2018-2019          5.00
# 4695  2018-2019          4.80
# 4697  2018-2019          4.50
#
# [1856 rows x 6 columns]

# %%
print(sorted(list(set(df['Season']))))
# Out:
# ['2000-2001', '2001-2002', '2002-2003', '2003-2004', '2004-2005', '2005-2006', '2006-2007', '2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016', '2016-2017', '2017-2018', '2018-2019']

# %%
'''
def convertSeason(DF, column, length):
    se = sorted(list(set(DF[column])))
    lista=[]
    for s in se:
        lista.append(int(s[:length]))
    return sorted(lista)

lista = convertSeason(df, 'Season', 4)
print(lista)
'''
# Out:
# "\ndef convertSeason(DF, column, length):\n    se = sorted(list(set(DF[column])))\n    lista=[]\n    for s in se:\n        lista.append(int(s[:length]))\n    return sorted(lista)\n\nlista = convertSeason(df, 'Season', 4)\nprint(lista)\n"

# %%
#for col in df['Season']:
    #print(col)

# %%
def convertSeason(DF, column, length):
    se = sorted(list(set(DF[column])))
    lista=[]
    for s in se:
        lista.append(s[:length])
    for col in DF[column]:
        for i in range(0,len(lista)):
            if col == se[i]:
                DF[column] = DF[column].replace({col: lista[i]})
    return DF
    

df = convertSeason(df, 'Season', 4)
# Out:
# /usr/local/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
def changeType(DF, column, types):
    DF[column] = DF[column].astype(types)
    return DF

df = changeType(df, 'Season', int)
# Out:
# /usr/local/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                      Name       Team_from     League_from       Team_to  \
# 0               Luís Figo    FC Barcelona          LaLiga   Real Madrid
# 1           Hernán Crespo           Parma         Serie A         Lazio
# 2           Marc Overmars         Arsenal  Premier League  FC Barcelona
# 3       Gabriel Batistuta      Fiorentina         Serie A       AS Roma
# 4          Nicolas Anelka     Real Madrid          LaLiga      Paris SG
# ...                   ...             ...             ...           ...
# 4689         Jens Odgaard           Inter         Serie A      Sassuolo
# 4690        Marco Carraro           Inter         Serie A      Atalanta
# 4692  Giangiacomo Magnani        Juventus         Serie A      Sassuolo
# 4695        Jasmin Kurtic        Atalanta         Serie A          SPAL
# 4697        Silvan Widmer  Udinese Calcio         Serie A      FC Basel
#
#       Season  Transfer_fee
# 0       2000         60.00
# 1       2000         56.81
# 2       2000         40.00
# 3       2000         36.15
# 4       2000         34.50
# ...      ...           ...
# 4689    2018          5.00
# 4690    2018          5.00
# 4692    2018          5.00
# 4695    2018          4.80
# 4697    2018          4.50
#
# [1856 rows x 6 columns]

# %%
def changeNamecol(DF, column, newname):
    DF = DF.rename(columns={column: newname})
    return DF

df = changeNamecol(df, 'Season', 'Summer')

# %%
df["Summer"].value_counts()
# Out:
# 2014    119
# 2011    118
# 2008    115
# 2009    114
# 2017    114
# 2016    110
# 2012    107
# 2015    104
# 2007    101
# 2013     99
# 2000     98
# 2018     96
# 2010     95
# 2001     90
# 2005     88
# 2006     83
# 2004     79
# 2002     64
# 2003     62
# Name: Summer, dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Team_from', 'League_from', 'Team_to', 'Summer',
#        'Transfer_fee'],
#       dtype='object')

# %%
df = changeType(df, 'Summer', str)

# %%
df['Name-season']=df['Name']+df['Summer']
df
# Out:
#                      Name       Team_from     League_from       Team_to  \
# 0               Luís Figo    FC Barcelona          LaLiga   Real Madrid
# 1           Hernán Crespo           Parma         Serie A         Lazio
# 2           Marc Overmars         Arsenal  Premier League  FC Barcelona
# 3       Gabriel Batistuta      Fiorentina         Serie A       AS Roma
# 4          Nicolas Anelka     Real Madrid          LaLiga      Paris SG
# ...                   ...             ...             ...           ...
# 4689         Jens Odgaard           Inter         Serie A      Sassuolo
# 4690        Marco Carraro           Inter         Serie A      Atalanta
# 4692  Giangiacomo Magnani        Juventus         Serie A      Sassuolo
# 4695        Jasmin Kurtic        Atalanta         Serie A          SPAL
# 4697        Silvan Widmer  Udinese Calcio         Serie A      FC Basel
#
#      Summer  Transfer_fee              Name-season
# 0      2000         60.00            Luís Figo2000
# 1      2000         56.81        Hernán Crespo2000
# 2      2000         40.00        Marc Overmars2000
# 3      2000         36.15    Gabriel Batistuta2000
# 4      2000         34.50       Nicolas Anelka2000
# ...     ...           ...                      ...
# 4689   2018          5.00         Jens Odgaard2018
# 4690   2018          5.00        Marco Carraro2018
# 4692   2018          5.00  Giangiacomo Magnani2018
# 4695   2018          4.80        Jasmin Kurtic2018
# 4697   2018          4.50        Silvan Widmer2018
#
# [1856 rows x 7 columns]

# %%
df.to_csv('./output/TransferLigas.csv', header=True, index=False)

# %%
import requests

def getPage(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    return soup

url = "https://es.wikipedia.org/wiki/Trofeo_Pichichi"
soup = getPage(url)
#soup

# %%
'''
res = requests.get("https://es.wikipedia.org/wiki/Trofeo_Pichichi")
html = res.text
html[:20]
'''
# Out:
# '\nres = requests.get("https://es.wikipedia.org/wiki/Trofeo_Pichichi")\nhtml = res.text\nhtml[:20]\n'

# %%
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')
soup
'''
# Out:
# "\nfrom bs4 import BeautifulSoup\nsoup = BeautifulSoup(html, 'html.parser')\nsoup\n"

# %%
jugador = soup.select('#mw-content-text > div > center > table > tbody > tr:nth-child(77) > td:nth-child(2) > a')

# %%
goles = soup.select('#mw-content-text > div > center > table > tbody > tr:nth-child(77) > td:nth-child(6)')

# %%
temporada = soup.select('#mw-content-text > div > center > table > tbody > tr:nth-child(79) > td:nth-child(1) > a')

# %%
def getPichichi(soup, postable, row, cellSeason, cellPlayers, cellGoals):
    table = soup.find_all('table')[postable]
    rows = table.find_all('tr')[row:]
    pichichi = []
    for row in rows:
        cells = row.find_all('td')
        pichichi.append({
            "season": re.sub("[()\\n]", "", cells[cellSeason].find('a').text),
            "players": re.sub("[0-9]?[()\\n]", "", cells[cellPlayers].text),
            "goals": int(re.sub("[()\\n]", "", cells[cellGoals].text)[:2])       
        })
    return pd.DataFrame(pichichi)

coso = getPichichi(soup, 1, 76, 0, 1, 5)
coso
# Out:
#      season              players  goals
# 0   1999–00       Salva Ballesta     27
# 1   2000–01       Raúl González      24
# 2   2001–02        Diego Tristán     21
# 3   2002–03           Roy Makaay     29
# 4   2003–04             Ronaldo      24
# 5   2004–05   Diego Forlán [27]​     25
# 6   2005–06         Samuel Eto'o     26
# 7   2006–07  Ruud van Nistelrooy     25
# 8   2007–08           Dani Güiza     27
# 9   2008–09        Diego Forlán      32
# 10  2009–10        Lionel Messi      34
# 11  2010–11   Cristiano Ronaldo      40
# 12  2011–12        Lionel Messi      50
# 13  2012–13        Lionel Messi      46
# 14  2013–14   Cristiano Ronaldo      31
# 15  2014–15   Cristiano Ronaldo      48
# 16  2015–16          Luis Suárez     40
# 17  2016–17        Lionel Messi      37
# 18  2017-18        Lionel Messi      34
# 19  2018-19        Lionel Messi      36

# %%
def subThings(DF, column, text):
    DF[column] = DF[column].replace('\[?[0-9]+\]?', text)
    return DF

coso = subThings(coso, 'players', "")
coso
# Out:
#      season              players  goals
# 0   1999–00       Salva Ballesta     27
# 1   2000–01       Raúl González      24
# 2   2001–02        Diego Tristán     21
# 3   2002–03           Roy Makaay     29
# 4   2003–04             Ronaldo      24
# 5   2004–05   Diego Forlán [27]​     25
# 6   2005–06         Samuel Eto'o     26
# 7   2006–07  Ruud van Nistelrooy     25
# 8   2007–08           Dani Güiza     27
# 9   2008–09        Diego Forlán      32
# 10  2009–10        Lionel Messi      34
# 11  2010–11   Cristiano Ronaldo      40
# 12  2011–12        Lionel Messi      50
# 13  2012–13        Lionel Messi      46
# 14  2013–14   Cristiano Ronaldo      31
# 15  2014–15   Cristiano Ronaldo      48
# 16  2015–16          Luis Suárez     40
# 17  2016–17        Lionel Messi      37
# 18  2017-18        Lionel Messi      34
# 19  2018-19        Lionel Messi      36

# %%
print(list(range(2000,2019)))
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
def convSeas(DF, column, range1, range2):
    lista = list(range(range1,range2))
    DF[column]=lista
    return DF

campeones=convSeas(coso, 'season', 2000, 2020)

# %%
'''
tabla = soup.find_all('table')[1]
filas = tabla.find_all('tr')[77:]
filas
'''
# Out:
# "\ntabla = soup.find_all('table')[1]\nfilas = tabla.find_all('tr')[77:]\nfilas\n"

# %%
'''
#TABLA
goleadores = []
for fila in filas:
    celdas = fila.find_all('td')
    goleadores.append({
        "temporadas": re.sub("[()\\n]", "", celdas[0].find('a').text),
        "jugadores": re.sub("[0-9]?[()\\n]", "", celdas[1].text),
        "goles": int(re.sub("[()\\n]", "", celdas[5].text)[:2])       
    })
    
print(goleadores)
'''
# Out:
# '\n#TABLA\ngoleadores = []\nfor fila in filas:\n    celdas = fila.find_all(\'td\')\n    goleadores.append({\n        "temporadas": re.sub("[()\\n]", "", celdas[0].find(\'a\').text),\n        "jugadores": re.sub("[0-9]?[()\\n]", "", celdas[1].text),\n        "goles": int(re.sub("[()\\n]", "", celdas[5].text)[:2])       \n    })\n    \nprint(goleadores)\n'

# %%
#pd.DataFrame(goleadores)

# %%
cosita=getPage("http://www.lalanternadelpopolo.it/Calcio%20-%20Capocannonieri%20Campionato%20Italia%20Albo%20d'Oro%20Vincitori.htm")

# %%
def getCapo(soup):
    table = cosita.find_all('table')[3]
    rows = table.select('tr')[77:97]
    capo = []
    for row in rows:
        cells = row.find_all('td')
        capo.append({
            "season": cells[0].text.strip(),
            "players": cells[1].text.strip(),
            "goals": cells[2].text.strip()})
    return pd.DataFrame(capo)

capoDf = getCapo(cosita)
capoDf
# Out:
#        season               players   goals
# 0        2000     Andriy Shevchenko      24
# 1        2001         Hernan Crespo      26
# 2        2002       David Trezeguet      24
# 3        2003       Christian Vieri      24
# 4        2004     Andriy Shevchenko      24
# 5        2005   Cristiano Lucarelli      24
# 6        2006             Luca Toni      31
# 7        2007       Francesco Totti      26
# 8        2008  Alessandro Del Piero      21
# 9        2009    Zlatan Ibrahimovic      25
# 10       2010     Antonio Di Natale      29
# 11       2011     Antonio Di Natale      28
# 12       2012    Zlatan Ibrahimovic      28
# 13       2013        Edinson Cavani      29
# 14       2014         Ciro Immobile      22
# 15       2015          Mauro Icardi      22
# 16  Luca Toni                    22  Verona
# 17       2016       Gonzalo Higuain      36
# 18       2017            Edin Dzeko      29
# 19       2018          Mauro Icardi      29

# %%
#dos = capoDf[16].shift(1, axis = 1) 
#dos
#capoDf.iloc[16]
#capoDf.loc[16], ['season', 'players', 'goals']

# %%
def deleteRow(DF, row):
    DF = DF.drop(row)
    return DF

italianos = deleteRow(capoDf, 16)
#italianos

# %%
#def subThings(DF, column, text):
#    DF[column] = DF[column].replace('[A-Z]+?[a-z]+?\s?[A-Z]+?[a-z]+', text)
#    return DF

# %%
top = getPage('https://www.worldfootball.net/top_scorer/eng-premier-league/')

# %%
def getTop(soup):
    table = top.find_all('table')[0]
    rows = table.select('tr')[1:24]
    rows
    tp = []
    for row in rows:
        cells = row.find_all('td')
        tp.append({
            "season": cells[0].text.strip(),
            "players": cells[2].text.strip(),
            "goals": cells[5].text.strip()})
    return pd.DataFrame(tp).sort_values('season')

topPL = getTop(top)
topPL
# Out:
#        season                    players goals
# 11                         Carlos TÃ©vez    21
# 1              Pierre-Emerick Aubameyang    22
# 2                          Mohamed Salah    22
# 22  1999/2000             Kevin Phillips    30
# 21  2000/2001    Jimmy Floyd Hasselbaink    23
# 20  2001/2002              Thierry Henry    24
# 19  2002/2003        Ruud van Nistelrooy    25
# 18  2003/2004              Thierry Henry    30
# 17  2004/2005              Thierry Henry    25
# 16  2005/2006              Thierry Henry    27
# 15  2006/2007              Didier Drogba    20
# 14  2007/2008          Cristiano Ronaldo    31
# 13  2008/2009             Nicolas Anelka    19
# 12  2009/2010              Didier Drogba    29
# 10  2010/2011           Dimitar Berbatov    21
# 9   2011/2012           Robin van Persie    30
# 8   2012/2013           Robin van Persie    26
# 7   2013/2014               Luis SuÃ¡rez    31
# 6   2014/2015                Kun AgÃ¼ero    26
# 5   2015/2016                 Harry Kane    25
# 4   2016/2017                 Harry Kane    29
# 3   2017/2018              Mohamed Salah    32
# 0   2018/2019                Sadio ManÃ©    22

# %%
nope = deleteRow(topPL, [1,2,11])
#for season in nope['season']:
    #print(season)
  #  count=1999
nope['season']=nope['season'].replace('.+', "hola")
nope
# Out:
#        season                  players goals
# 22  1999/2000           Kevin Phillips    30
# 21  2000/2001  Jimmy Floyd Hasselbaink    23
# 20  2001/2002            Thierry Henry    24
# 19  2002/2003      Ruud van Nistelrooy    25
# 18  2003/2004            Thierry Henry    30
# 17  2004/2005            Thierry Henry    25
# 16  2005/2006            Thierry Henry    27
# 15  2006/2007            Didier Drogba    20
# 14  2007/2008        Cristiano Ronaldo    31
# 13  2008/2009           Nicolas Anelka    19
# 12  2009/2010            Didier Drogba    29
# 10  2010/2011         Dimitar Berbatov    21
# 9   2011/2012         Robin van Persie    30
# 8   2012/2013         Robin van Persie    26
# 7   2013/2014             Luis SuÃ¡rez    31
# 6   2014/2015              Kun AgÃ¼ero    26
# 5   2015/2016               Harry Kane    25
# 4   2016/2017               Harry Kane    29
# 3   2017/2018            Mohamed Salah    32
# 0   2018/2019              Sadio ManÃ©    22

# %%
ingleses = convSeas(nope, 'season', 2000, 2020)

# %%
french = getPage('https://es.wikipedia.org/wiki/Anexo:M%C3%A1ximos_goleadores_de_la_Liga_Francesa')

def getL1(soup):
    table = soup.find_all('table')[0]
    rows = table.find_all('tr')[62:]
    fr = []
    for row in rows:
        cells = row.find_all('td')
        fr.append({
            "season": cells[0].text.strip(),
                "players": cells[1].text.strip(),
                "goals": cells[3].text.strip()})
    return pd.DataFrame(fr)

#getL1(french)

# %%
holl = getPage('https://es.wikipedia.org/wiki/Anexo:M%C3%A1ximos_goleadores_de_la_Eredivisie')
def getL1(soup):
    table = soup.find_all('table')[0]
    rows = table.find_all('tr')[44:]
    fr = []
    for row in rows:
        cells = row.find_all('td')
        fr.append({
            "season": cells[0].text.strip(),
                "players": cells[1].text.strip(),
                "goals": cells[2].text.strip()})
    return pd.DataFrame(fr)

#getL1(holl)

# %%
def getWiki(soup, postable, posrows, posSeason, posPlayers, posGoals):
    table = soup.find_all('table')[postable]
    rows = table.find_all('tr')[posrows:]
    wiki = []
    for row in rows:
        cells = row.find_all('td')
        wiki.append({
            "season": cells[posSeason].text.strip(),
                "players": cells[posPlayers].text.strip(),
                "goals": cells[posGoals].text.strip()})
    return pd.DataFrame(wiki)

holland = getWiki(holl, 0, 44, 0, 1, 2)

# %%
frenchs = getWiki(french, 0, 62, 0, 1, 3)

# %%
bund = getPage('https://es.wikipedia.org/wiki/Anexo:Estad%C3%ADsticas_de_la_Bundesliga_de_Alemania')
bundSc = getWiki(bund, 3, 37, 0, 1, 3)
#bundSc

# %%
holi=convSeas(holland, 'season', 2000, 2019)
holandeses = subChar(holi, 'players', 'ž', 'z')
#holandeses

# %%
fr = convSeas(frenchs, 'season', 2000, 2018)
#fr

# %%
alemanes = convSeas(bundSc, 'season', 2000, 2019)
alemanes.dtypes
# Out:
# season      int64
# players    object
# goals      object
# dtype: object

# %%
def subChar(DF, column, old, new):
    DF[column] = DF[column].str.replace(old, new)
    return DF

alemanes = subChar(alemanes, 'players', 'ž', 'z')
alemanes = subChar(alemanes, 'players', ' Martin Max', '')
alemanes = subChar(alemanes, 'players', ' Ebbe Sand', '')
alemanes = subChar(alemanes, 'players', ' Thomas Christiansen', '')
#alemanes

# %%
fr=subChar(fr, 'players', 'CisséPauleta', 'Cissé')
fr=subChar(fr, 'players', 'ć', 'c')
franceses=subChar(fr, 'players', ' Nené', '')
#franceses

# %%
ingleses=subChar(ingleses, 'players', 'Kun\s.+', 'Sergio Agüero')
ingleses=subChar(ingleses, 'players', 'Su.+', 'Suárez')
ingleses=subChar(ingleses, 'players', 'Ma.+', 'Mané')
#ingleses

# %%
pichichi=subChar(campeones, 'players', '\s\[[0-9]+\]', '')
pichichi
# Out:
#     season              players  goals
# 0     2000       Salva Ballesta     27
# 1     2001       Raúl González      24
# 2     2002        Diego Tristán     21
# 3     2003           Roy Makaay     29
# 4     2004             Ronaldo      24
# 5     2005        Diego Forlán​     25
# 6     2006         Samuel Eto'o     26
# 7     2007  Ruud van Nistelrooy     25
# 8     2008           Dani Güiza     27
# 9     2009        Diego Forlán      32
# 10    2010        Lionel Messi      34
# 11    2011   Cristiano Ronaldo      40
# 12    2012        Lionel Messi      50
# 13    2013        Lionel Messi      46
# 14    2014   Cristiano Ronaldo      31
# 15    2015   Cristiano Ronaldo      48
# 16    2016          Luis Suárez     40
# 17    2017        Lionel Messi      37
# 18    2018        Lionel Messi      34
# 19    2019        Lionel Messi      36

# %%
import sys
import argparse
import subprocess

def recibeConfig():
    parser = argparse.ArgumentParser(description='¿Será el pichichi el fichaje del verano?')
    parser.add_argument('--summer',
                        help='Summer transfer market between 2000-2019',
                        '--league',
                        help='Select league Bundesliga, LaLiga, Premier League, League One, Serie A, Eredivisie
                        )
                        
    args = parser.parse_args()
    print(args)
    return args
# Out:
#   File "<ipython-input-64-e5df5de6b06f>", line 10
#     help='Select league Bundesliga, LaLiga, Premier League, League One, Serie A, Eredivisie
#                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
#pichichi(season,players,goals), ingleses, franceses, alemanes, holandeses, italianos

# %%
df.columns
# Out:
# Index(['Name', 'Team_from', 'League_from', 'Team_to', 'Summer', 'Transfer_fee',
#        'Name-season'],
#       dtype='object')

# %%
df = changeType(df, 'Name', str)
pichichi = changeType(pichichi, 'players', str)
pichichi = changeType(pichichi, 'season', int)

# %%
'''
for row in df.iterrows():
    for players in pichichi['players']:
        for seas in pichichi['season']:
            if players == str(row) and str(seas) == str(row):
                print(row)
 '''
# Out:
# "\nfor row in df.iterrows():\n    for players in pichichi['players']:\n        for seas in pichichi['season']:\n            if players == str(row) and str(seas) == str(row):\n                print(row)\n "

# %%
def combCol(DF, nameNew, column1, column2):
    DF[nameNew] = DF[column1]+DF[column2]
    return DF

# %%
'''
for names in df['Name']:
    for players in pichichi['players']:
        for summer in df['Summer']:
            for pichi in pichichi['season']:
                if names == players and summer == pichi:
                    print(True)
 '''   
#if (yourValue in df[cols]:
#        print('Found in '+cols)
#if df['Name'] in pichichi['players'] and df['Summer'] == pichichi['season']:
#    print(True)
# Out:
# "\nfor names in df['Name']:\n    for players in pichichi['players']:\n        for summer in df['Summer']:\n            for pichi in pichichi['season']:\n                if names == players and summer == pichi:\n                    print(True)\n "

# %%
todos = pd.concat([pichichi, ingleses, franceses, alemanes, holandeses, italianos])
todos
# Out:
#    season          players goals
# 0    2000   Salva Ballesta    27
# 1    2001   Raúl González     24
# 2    2002    Diego Tristán    21
# 3    2003       Roy Makaay    29
# 4    2004         Ronaldo     24
# ..    ...              ...   ...
# 14   2014    Ciro Immobile    22
# 15   2015     Mauro Icardi    22
# 17   2016  Gonzalo Higuain    36
# 18   2017       Edin Dzeko    29
# 19   2018     Mauro Icardi    29
#
# [115 rows x 3 columns]

# %%
bundT = changeType(alemanes, 'season', str)
frenchT = changeType(franceses, 'season', str)
hollT = changeType(holandeses, 'season', str)
premierT = changeType(ingleses, 'season', str)
spainT = changeType(pichichi, 'season', str)
italyT = changeType(italianos, 'season', str)

# %%
bundT = combCol(bundT, 'Comb', 'players', 'season')
frenchT = combCol(frenchT, 'Comb', 'players', 'season')
hollT = combCol(hollT, 'Comb', 'players', 'season')
premierT = combCol(premierT, 'Comb', 'players', 'season')
spainT = combCol(spainT, 'Comb', 'players', 'season')
italyT = combCol(italyT, 'Comb', 'players', 'season')
hollT
# Out:
#    season               players goals                      Comb
# 0    2000   Ruud van Nistelrooy    29   Ruud van Nistelrooy2000
# 1    2001         Mateja Kezman    24         Mateja Kezman2001
# 2    2002  Pierre van Hooijdonk    24  Pierre van Hooijdonk2002
# 3    2003         Mateja Kezman    35         Mateja Kezman2003
# 4    2004         Mateja Kezman    31         Mateja Kezman2004
# 5    2005            Dirk Kuijt    29            Dirk Kuijt2005
# 6    2006   Klaas-Jan Huntelaar    33   Klaas-Jan Huntelaar2006
# 7    2007          Afonso Alves    34          Afonso Alves2007
# 8    2008   Klaas-Jan Huntelaar    33   Klaas-Jan Huntelaar2008
# 9    2009    Mounir El Hamdaoui    23    Mounir El Hamdaoui2009
# 10   2010           Luis Suárez    35           Luis Suárez2010
# 11   2011       Björn Vleminckx    23       Björn Vleminckx2011
# 12   2012              Bas Dost    32              Bas Dost2012
# 13   2013         Wilfried Bony    31         Wilfried Bony2013
# 14   2014    Alfreð Finnbogason    27    Alfreð Finnbogason2014
# 15   2015         Memphis Depay    22         Memphis Depay2015
# 16   2016       Vincent Janssen    27       Vincent Janssen2016
# 17   2017     Nicolai Jørgensen    21     Nicolai Jørgensen2017
# 18   2018   Alireza Jahanbakhsh    21   Alireza Jahanbakhsh2018

# %%
listaza=df[0:0]
#listin = []
for name in df['Name-season']:
    for player in italyT['Comb']:
        if name == player:  
            #listin.append(df.loc[df['Name-season'] == name])
            listaza = listaza.append(df.loc[df['Name-season'] == name])

#listaza=[]
#for i in range(0,len(listin)):
#    listaza.append(listin[i].loc[listin[i]['Summer']=='2009')
listaza
# Out:
#                     Name   Team_from League_from        Team_to Summer  \
# 2227  Zlatan Ibrahimovic       Inter     Serie A   FC Barcelona   2009
# 2980  Zlatan Ibrahimovic    AC Milan     Serie A       Paris SG   2012
# 3219      Edinson Cavani  SSC Napoli     Serie A       Paris SG   2013
# 3499       Ciro Immobile      Torino     Serie A  Bor. Dortmund   2014
# 3567       Ciro Immobile    Juventus     Serie A         Torino   2014
# 3499       Ciro Immobile      Torino     Serie A  Bor. Dortmund   2014
# 3567       Ciro Immobile    Juventus     Serie A         Torino   2014
#
#       Transfer_fee             Name-season
# 2227          69.5  Zlatan Ibrahimovic2009
# 2980          21.0  Zlatan Ibrahimovic2012
# 3219          64.5      Edinson Cavani2013
# 3499          18.5       Ciro Immobile2014
# 3567           8.0       Ciro Immobile2014
# 3499          18.5       Ciro Immobile2014
# 3567           8.0       Ciro Immobile2014

# %%
listaza[listaza['Summer']==('2009')]
# Out:
#                     Name Team_from League_from       Team_to Summer  \
# 2227  Zlatan Ibrahimovic     Inter     Serie A  FC Barcelona   2009
#
#       Transfer_fee             Name-season
# 2227          69.5  Zlatan Ibrahimovic2009

# %%
listaza.dtypes
# Out:
# Name             object
# Team_from        object
# League_from      object
# Team_to          object
# Summer           object
# Transfer_fee    float64
# Name-season      object
# dtype: object

# %%
def generator(league, year):  
    newDF=df[0:0]
    for name in df['Name-season']:
        for player in league['Comb']:
            if name == player:  
                newDF = newDF.append(df.loc[df['Name-season'] == name])
    return newDF.loc[newDF['Summer']==(year)]

x = generator(hollT, '2012')
x
# Out:
#           Name   Team_from League_from        Team_to Summer  Transfer_fee  \
# 3078  Bas Dost  Heerenveen  Eredivisie  VfL Wolfsburg   2012           7.0
#
#        Name-season
# 3078  Bas Dost2012

# %%
df.dtypes
# Out:
# Name             object
# Team_from        object
# League_from      object
# Team_to          object
# Summer           object
# Transfer_fee    float64
# Name-season      object
# dtype: object

# %%
perotio = [bundT, frenchT, hollT, premierT, spainT, italyT]

# %%
for i in range(0,len(perotio)):
    print(i)
for pe in perotio:
    pe[0]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-bdffd4f872e1> in <module>
#       2     print(i)
#       3 for pe in perotio:
# ----> 4     pe[0]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
df
# Out:
#                      Name       Team_from     League_from       Team_to  \
# 0               Luís Figo    FC Barcelona          LaLiga   Real Madrid
# 1           Hernán Crespo           Parma         Serie A         Lazio
# 2           Marc Overmars         Arsenal  Premier League  FC Barcelona
# 3       Gabriel Batistuta      Fiorentina         Serie A       AS Roma
# 4          Nicolas Anelka     Real Madrid          LaLiga      Paris SG
# ...                   ...             ...             ...           ...
# 4689         Jens Odgaard           Inter         Serie A      Sassuolo
# 4690        Marco Carraro           Inter         Serie A      Atalanta
# 4692  Giangiacomo Magnani        Juventus         Serie A      Sassuolo
# 4695        Jasmin Kurtic        Atalanta         Serie A          SPAL
# 4697        Silvan Widmer  Udinese Calcio         Serie A      FC Basel
#
#      Summer  Transfer_fee              Name-season
# 0      2000         60.00            Luís Figo2000
# 1      2000         56.81        Hernán Crespo2000
# 2      2000         40.00        Marc Overmars2000
# 3      2000         36.15    Gabriel Batistuta2000
# 4      2000         34.50       Nicolas Anelka2000
# ...     ...           ...                      ...
# 4689   2018          5.00         Jens Odgaard2018
# 4690   2018          5.00        Marco Carraro2018
# 4692   2018          5.00  Giangiacomo Magnani2018
# 4695   2018          4.80        Jasmin Kurtic2018
# 4697   2018          4.50        Silvan Widmer2018
#
# [1856 rows x 7 columns]

# %%
newDF=df[0:0]
newDF = newDF.append(pd.Series(['Castolo', 'London Blue', 'Premier League', 'Internazionale', '2020', 100, 'Castolo2020'], index=['Name', 'Team_from', 'League_from', 'Team_to', 'Summer', 'Transfer_fee', 'Name-season']), ignore_index=True)

# %%
newDF
# Out:
#       Name    Team_from     League_from         Team_to Summer  Transfer_fee  \
# 0  Castolo  London Blue  Premier League  Internazionale   2020         100.0
#
#    Name-season
# 0  Castolo2020

# %%
# !pip3 install FPDF
# Out:
# Requirement already satisfied: FPDF in /usr/local/lib/python3.7/site-packages (1.7.2)

# %%
from fpdf import FPDF
pdf = FPDF()
pdf.add_page()
pdf.image("./output/castolo.jpeg", x=60, y=30, w=100)
pdf.set_font("Arial", size=12)
#pdf.cell(200, 50, txt="Total Volume", ln=1)
#pdf.ln(85)  # move 85 down
#pdf.image("./output/averageprice.png", x=110, y=30, w=100)
#pdf.set_font("Arial", size=12)
#pdf.cell(200, 500, txt="Average Price", ln=1)
pdf.ln(85)  # move 85 down
pdf.cell(200, 15, txt="Not coincidence this year and this league", ln=1, align="C")
pdf.output("./output/add_image.pdf")
# Out:
# ''

# %%
def createPDF(x):
    pdf = FPDF()
    pdf.add_page()
    pdf.image("./output/castolo.jpeg", x=60, y=30, w=100)
    pdf.set_font("Arial", size=12)
    pdf.ln(85)  # move 85 down
    pdf.cell(200, 5, txt=x, ln=1, align="C")
    return pdf.output("./output/result.pdf")

createPDF(x)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-8d511ab72be9> in <module>
#       8     return pdf.output("./output/result.pdf")
#       9
# ---> 10 createPDF(x)
#
# <ipython-input-86-8d511ab72be9> in createPDF(x)
#       5     pdf.set_font("Arial", size=12)
#       6     pdf.ln(85)  # move 85 down
# ----> 7     pdf.cell(200, 5, txt=x, ln=1, align="C")
#       8     return pdf.output("./output/result.pdf")
#       9
#
# /usr/local/lib/python3.7/site-packages/fpdf/fpdf.py in wrapper(self, *args, **kwargs)
#     148                 self.error("No page open, you need to call add_page() first")
#     149             else:
# --> 150                 return fn(self, *args, **kwargs)
#     151         return wrapper
#     152
#
# /usr/local/lib/python3.7/site-packages/fpdf/fpdf.py in cell(self, w, h, txt, border, ln, align, fill, link)
#     720             if('B' in border):
#     721                 s+=sprintf('%.2f %.2f m %.2f %.2f l S ',x*k,(self.h-(y+h))*k,(x+w)*k,(self.h-(y+h))*k)
# --> 722         if(txt!=''):
#     723             if(align=='R'):
#     724                 dx=w-self.c_margin-self.get_string_width(txt)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
